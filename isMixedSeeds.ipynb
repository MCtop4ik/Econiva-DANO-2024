# %%
import pandas as pd

df = pd.read_csv('merged-dataset.csv', parse_dates=['start_date', 'end_date'])
# Out:
# /var/folders/pn/0bn7dksx05d8k5q8rpx3vxm80000gn/T/ipykernel_20280/325539370.py:3: DtypeWarning: Columns (12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('merged-dataset.csv', parse_dates=['start_date', 'end_date'])
# /var/folders/pn/0bn7dksx05d8k5q8rpx3vxm80000gn/T/ipykernel_20280/325539370.py:3: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('merged-dataset.csv', parse_dates=['start_date', 'end_date'])
# /var/folders/pn/0bn7dksx05d8k5q8rpx3vxm80000gn/T/ipykernel_20280/325539370.py:3: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('merged-dataset.csv', parse_dates=['start_date', 'end_date'])

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.columns
# Out:
# Index(['season', 'field', 'work_type', 'work_subtype', 'start_date',
#        'end_date', 'completed_work_area', 'main_tech', 'add_tech', 'mech',
#        'proc_depth', 'prod_purpose', 'prod_weight', 'prod_dry_perc',
#        'prod_humid', 'prod_impur', 'yield_fact', 'work_id', 'region',
#        'land_type', 'fertility_score', 'crop', 'crop_predecessor',
#        'crop_yearold', 'field_area', 'hybrid', 'reproduction', 'seed_origin',
#        'technology', 'yield_plan', 'p2o5', 'k2o', 'humus', 'ph',
#        'inv_item_type', 'inv_item_name', 'inv_item_weight', 'inv_item_unit',
#        'inv_item_dose', 'inv_item_date'],
#       dtype='object')

# %%
df.head()
# Out:
#    season            field        work_type work_subtype start_date  \
# 0    2023  16.13.12.044.00  Обработка почвы  Боронование 2022-04-29
# 1    2023  16.13.12.017.00  Обработка почвы  Боронование 2022-05-01
# 2    2023  16.13.12.012.00  Обработка почвы  Боронование 2022-05-02
# 3    2023  16.13.12.012.00  Обработка почвы  Боронование 2022-05-02
# 4    2023  16.13.12.017.00  Обработка почвы  Боронование 2022-05-02
#
#     end_date completed_work_area  \
# 0 2022-04-30               49,78
# 1 2022-05-02              154,76
# 2 2022-05-03               40,62
# 3 2022-05-03               86,00
# 4 2022-05-03               76,00
#
#                                            main_tech  \
# 0  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 1  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 2  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 3  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 4  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
#
# ...

# %%
df.sort_values(by='start_date', ascending=True).reset_index()
# Out:
#          index  season            field        work_type         work_subtype  \
# 0            0    2023  16.13.12.044.00  Обработка почвы          Боронование
# 1            1    2023  16.13.12.017.00  Обработка почвы          Боронование
# 2            2    2023  16.13.12.012.00  Обработка почвы          Боронование
# 3            3    2023  16.13.12.012.00  Обработка почвы          Боронование
# 4            4    2023  16.13.12.017.00  Обработка почвы          Боронование
# ...        ...     ...              ...              ...                  ...
# 228631  228616    2024  54.28.07.028.00  Обработка почвы          Культивация
# 228632  228624    2024  40.04.07.010.00           Уборка  Уборка силос/карнаж
# 228633  228634    2024  54.28.07.028.00  Обработка почвы          Культивация
# 228634  228633    2024  54.28.07.028.00  Обработка почвы          Культивация
# 228635  228635    2024  54.17.02.022.00           Уборка                Вывоз
#
# ...
