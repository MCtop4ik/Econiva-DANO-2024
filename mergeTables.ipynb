# %%
import pandas as pd

# %%
works = pd.read_csv('ekoniva-dataset/works.csv')
fields = pd.read_csv('ekoniva-dataset/fields.csv')
value = pd.read_csv('ekoniva-dataset/value.csv', parse_dates=['inv_item_date'], dayfirst=True)

# %%
works.head()
# Out:
#    season            field        work_type work_subtype  start_date  \
# 0    2023  16.13.12.044.00  Обработка почвы  Боронование  29.04.2022
# 1    2023  16.13.12.017.00  Обработка почвы  Боронование  01.05.2022
# 2    2023  16.13.12.012.00  Обработка почвы  Боронование  02.05.2022
# 3    2023  16.13.12.012.00  Обработка почвы  Боронование  02.05.2022
# 4    2023  16.13.12.017.00  Обработка почвы  Боронование  02.05.2022
#
#      end_date    area                                          main_tech  \
# 0  30.04.2022   49,78  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 1  02.05.2022  154,76  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 2  03.05.2022   40,62  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 3  03.05.2022   86,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 4  03.05.2022   76,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
#
#                                          add_tech  \
# 0                            Арендованная техника
# 1  Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 2                            Арендованная техника
# 3  Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 4  Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
#
#                            mech proc_depth prod_purpose prod_weight  \
# 0    Ахметсафин Айрат Рафикович      10,00          NaN        0,00
# 1   Ямалетдинов Фарид Расыхович      10,00          NaN        0,00
# 2  Мухаметзянов Ринат Айратович      10,00          NaN        0,00
# 3        Шакиров Ринат Галиевич      10,00          NaN        0,00
# 4        Шакиров Ринат Галиевич      10,00          NaN        0,00
#
#   prod_dry_perc prod_humid prod_impur yield_fact  \
# 0           NaN        NaN        NaN       0,00
# 1           NaN        NaN        NaN       0,00
# 2           NaN        NaN        NaN       0,00
# 3           NaN        NaN        NaN       0,00
# 4           NaN        NaN        NaN       0,00
#
#                                 work_id
# 0  A06AD38A-5448-40EC-B095-4B8918B4AC10
# 1  62B13DCE-FFB5-4E7A-8F1B-88930BD338EF
# 2  D5884A6D-4710-4C0A-8E5A-878291B89846
# 3  7A504837-1127-4315-ACF1-171AC80111BF
# 4  7FE86DA8-614B-4EBE-85CB-6AF80C08689F

# %%
fields.head()
# Out:
#              field region land_type  fertility_score  season  \
# 0  22.47.01.001.01  Алтай     пашня              NaN    2023
# 1  22.47.01.001.02  Алтай     пашня              NaN    2023
# 2  22.47.01.002.00  Алтай     пашня              4.0    2023
# 3  22.47.01.003.00  Алтай     пашня              4.0    2023
# 4  22.47.01.004.00  Алтай     пашня              3.0    2023
#
#                 crop        crop_predecessor  crop_yearold    area   hybrid  \
# 0  Оз.пшеница мягкая  Пар; Яр.пшеница мягкая           NaN  306,22  Скипетр
# 1                Пар  Пар; Яр.пшеница мягкая           NaN   63,16      NaN
# 2                Пар       Яр.пшеница мягкая           NaN  485,79      NaN
# 3  Оз.пшеница мягкая                     Пар           NaN  452,25  Скипетр
# 4  Оз.пшеница мягкая                     Пар           NaN  269,64  Скипетр
#
#   reproduction seed_origin   technology yield_plan    p2o5     k2o humus    ph
# 0           ЭС    Покупные  минимальная       3,80  243,16  226,93  4,46  5,78
# 1          NaN         NaN  минимальная        NaN  243,16  226,93  4,46  5,78
# 2          NaN         NaN          NaN        NaN  219,78  204,60  3,85  5,72
# 3           ЭС    Покупные  минимальная       3,80  205,15  192,28  6,49  5,94
# 4           ЭС    Покупные  минимальная       3,80  183,26  162,69  6,16  5,94

# %%
value.head()
# Out:
#              field inv_item_type inv_item_name inv_item_weight inv_item_unit  \
# 0  36.01.21.025.01     Удобрения  Удобрение 31        15017,60            кг
# 1  36.14.12.064.00     Удобрения  Удобрение 31         6500,00            м3
# 2  36.14.16.008.00     Удобрения  Удобрение 49         7865,00             т
# 3  36.14.16.008.00     Удобрения  Удобрение 49        10985,00             т
# 4  36.14.16.008.00     Удобрения  Удобрение 49        10985,00             т
#
#   inv_item_dose inv_item_date                               work_id
# 0        260,00    2024-10-28  E3A7DAEB-D124-4685-ADE1-199818C77361
# 1         65,00    2024-10-28  0AB8C8D7-04BD-4483-98B2-3E062CDD7E3E
# 2         65,00    2024-10-28  00E51F81-0A4F-4983-B068-877A089FFD33
# 3         65,00    2024-10-28  150F0150-8061-4CE9-9570-B112CBAD7C51
# 4         65,00    2024-10-28  D5D1EADB-D159-4CF8-8C2A-171517ACD403

# %%
df_intermediate = works.merge(fields, 'left', on=['field', 'season'])

# %%
df_intermediate.columns
# Out:
# Index(['season', 'field', 'work_type', 'work_subtype', 'start_date',
#        'end_date', 'area_x', 'main_tech', 'add_tech', 'mech', 'proc_depth',
#        'prod_purpose', 'prod_weight', 'prod_dry_perc', 'prod_humid',
#        'prod_impur', 'yield_fact', 'work_id', 'region', 'land_type',
#        'fertility_score', 'crop', 'crop_predecessor', 'crop_yearold', 'area_y',
#        'hybrid', 'reproduction', 'seed_origin', 'technology', 'yield_plan',
#        'p2o5', 'k2o', 'humus', 'ph'],
#       dtype='object')

# %%
df = df_intermediate.merge(value, "left", on=["field", "work_id"])

# %%
df = df.rename(columns={
    'area_x': 'completed_work_area',
    'area_y': 'field_area'
})

# %%
df.head(30)
# Out:
#     season            field        work_type   work_subtype  start_date  \
# 0     2023  16.13.12.044.00  Обработка почвы    Боронование  29.04.2022
# 1     2023  16.13.12.017.00  Обработка почвы    Боронование  01.05.2022
# 2     2023  16.13.12.012.00  Обработка почвы    Боронование  02.05.2022
# 3     2023  16.13.12.012.00  Обработка почвы    Боронование  02.05.2022
# 4     2023  16.13.12.017.00  Обработка почвы    Боронование  02.05.2022
# 5     2023  16.13.12.017.00  Обработка почвы    Боронование  02.05.2022
# 6     2023  16.13.12.012.00  Обработка почвы    Боронование  24.05.2022
# 7     2023  16.13.12.044.00  Обработка почвы    Боронование  24.05.2022
# 8     2023  16.13.12.017.00  Обработка почвы    Боронование  25.05.2022
# 9     2023  16.13.12.017.00  Обработка почвы    Боронование  26.05.2022
# 10    2023  40.22.02.002.00  Обработка почвы     Дискование  01.06.2022
# 11    2023  40.22.02.003.00  Обработка почвы     Дискование  01.06.2022
# 12    2023  40.22.02.004.00  Обработка почвы     Дискование  01.06.2022
# 13    2023  40.22.02.005.00  Обработка почвы     Дискование  01.06.2022
# 14    2023  40.22.02.001.00  Обработка почвы        Вспашка  01.06.2022
# 15    2023  16.13.12.017.00     Внесение СЗР  Обработка СЗР  05.06.2022
# 16    2023  16.13.12.017.00     Внесение СЗР  Обработка СЗР  05.06.2022
# 17    2023  16.13.12.044.00  Обработка почвы     Дискование  06.06.2022
# 18    2023  16.13.12.044.00  Обработка почвы     Дискование  06.06.2022
# 19    2023  16.13.12.044.00  Обработка почвы     Дискование  06.06.2022
# 20    2023  40.22.02.001.00  Обработка почвы     Дискование  08.06.2022
# 21    2023  16.13.19.045.00  Обработка почвы    Культивация  15.06.2022
# 22    2023  16.13.19.046.00  Обработка почвы    Культивация  15.06.2022
# 23    2023  16.13.19.048.00  Обработка почвы    Культивация  15.06.2022
# 24    2023  16.13.19.038.00  Обработка почвы    Культивация  16.06.2022
# 25    2023  16.13.19.055.00  Обработка почвы    Культивация  16.06.2022
# 26    2023  16.13.19.058.00  Обработка почвы    Культивация  16.06.2022
# 27    2023  16.13.19.038.00  Обработка почвы    Культивация  17.06.2022
# 28    2023  16.13.19.056.00  Обработка почвы    Культивация  17.06.2022
# 29    2023  16.13.19.058.00  Обработка почвы    Культивация  17.06.2022
#
#       end_date field_area                                          main_tech  \
# 0   30.04.2022      49,78  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 1   02.05.2022     154,76  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 2   03.05.2022      40,62  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 3   03.05.2022      86,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 4   03.05.2022      76,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 5   03.05.2022       5,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 6   25.05.2022     126,62  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 7   24.05.2022      49,78  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 8   26.05.2022     137,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 9   26.05.2022      98,76  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 10  01.06.2022      30,20  Трактор колесный John Deere 8295R, гос.ном. 39...
# 11  01.06.2022      31,74  Трактор колесный John Deere 8295R, гос.ном. 39...
# 12  01.06.2022      32,70  Трактор колесный John Deere 8295R, гос.ном. 39...
# 13  01.06.2022      10,81  Трактор колесный John Deere 8295R, гос.ном. 39...
# 14  01.06.2022      75,03  Трактор колесный John Deere 8295R, гос.ном. 39...
# 15  06.06.2022     235,76  Трактор колесный Massey Ferguson 6713, гос.ном...
# 16  06.06.2022     235,76  Трактор колесный Massey Ferguson 6713, гос.ном...
# 17  06.06.2022      16,38  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 18  06.06.2022      22,70  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 19  06.06.2022      10,70  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 20  08.06.2022      75,03  Трактор колесный John Deere 8295R, гос.ном. 39...
# 21  15.06.2022      27,58  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
# 22  15.06.2022      24,14  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
# 23  15.06.2022       7,00  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
# 24  16.06.2022      40,00  Трактор колесный Ростсельмаш 2400, гос.ном. 26...
# 25  16.06.2022      47,49  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
# 26  16.06.2022       8,00  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
# 27  17.06.2022      41,00  Трактор колесный Ростсельмаш 2400, гос.ном. 26...
# 28  17.06.2022      58,00  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
# 29  17.06.2022      14,09  Трактор колесный Ростсельмаш 3575, гос.ном. 05...
#
#                                              add_tech  \
# 0                                Арендованная техника
# 1      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 2                                Арендованная техника
# 3      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 4      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 5      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 6      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 7      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 8      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 9      Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 10  Борона дисковая Lemken Rubin 9/600 KUA, инв.но...
# 11  Борона дисковая Lemken Rubin 9/600 KUA, инв.но...
# 12  Борона дисковая Lemken Rubin 9/600 KUA, инв.но...
# 13  Борона дисковая Lemken Rubin 9/600 KUA, инв.но...
# 14  Плуг отвальный Lemken Diamant 11 7+1 L100, зав...
# 15  Опрыскиватель прицепной навесной Kverneland iX...
# 16  Опрыскиватель прицепной навесной Kverneland iX...
# 17  Борона дисковая Комз Экспорт АДС-6 "Tigarbo", ...
# 18  Борона дисковая Комз Экспорт АДС-6 "Tigarbo", ...
# 19  Борона дисковая Комз Экспорт АДС-6 "Tigarbo", ...
# 20  Борона дисковая Lemken Rubin 9/600 KUA, инв.но...
# 21  Культиватор стерневой Vaderstad TopDown 700, з...
# 22  Культиватор стерневой Vaderstad TopDown 700, з...
# 23  Культиватор стерневой Vaderstad TopDown 700, з...
# 24  Культиватор стерневой Vaderstad TopDown 500, и...
# 25  Культиватор стерневой Vaderstad TopDown 700, з...
# 26  Культиватор стерневой Vaderstad TopDown 700, з...
# 27  Культиватор стерневой Vaderstad TopDown 500, и...
# 28  Культиватор стерневой Vaderstad TopDown 700, з...
# 29  Культиватор стерневой Vaderstad TopDown 700, з...
#
#                              mech  ...    p2o5     k2o humus    ph  \
# 0      Ахметсафин Айрат Рафикович  ...  217,43  211,57  6,60  6,20
# 1     Ямалетдинов Фарид Расыхович  ...  232,65  216,06  8,80  6,75
# 2    Мухаметзянов Ринат Айратович  ...  247,50  216,33  8,58  7,33
# 3          Шакиров Ринат Галиевич  ...  247,50  216,33  8,58  7,33
# 4          Шакиров Ринат Галиевич  ...  232,65  216,06  8,80  6,75
# 5          Шакиров Ринат Галиевич  ...  232,65  216,06  8,80  6,75
# 6          Шакиров Ринат Галиевич  ...  247,50  216,33  8,58  7,33
# 7          Шакиров Ринат Галиевич  ...  217,43  211,57  6,60  6,20
# 8     Ямалетдинов Фарид Расыхович  ...  232,65  216,06  8,80  6,75
# 9          Шакиров Ринат Галиевич  ...  232,65  216,06  8,80  6,75
# 10         Малкоч Иван Васильевич  ...    0,00    0,00  0,00  0,00
# 11         Малкоч Иван Васильевич  ...    0,00    0,00  0,00  0,00
# 12         Малкоч Иван Васильевич  ...    0,00    0,00  0,00  0,00
# 13         Малкоч Иван Васильевич  ...    0,00    0,00  0,00  0,00
# 14    Ромашин Игорь Александрович  ...    0,00    0,00  0,00  0,00
# 15    Устимов Денис Александрович  ...  232,65  216,06  8,80  6,75
# 16    Устимов Денис Александрович  ...  232,65  216,06  8,80  6,75
# 17         Шакиров Ринат Галиевич  ...  217,43  211,57  6,60  6,20
# 18    Ямалетдинов Фарид Расыхович  ...  217,43  211,57  6,60  6,20
# 19         Шакиров Ринат Галиевич  ...  217,43  211,57  6,60  6,20
# 20         Малкоч Иван Васильевич  ...    0,00    0,00  0,00  0,00
# 21   Хабибуллин Ленар Габдуллович  ...   58,30  170,50  6,71  6,05
# 22   Хабибуллин Ленар Габдуллович  ...  425,70  276,10  7,59  7,26
# 23   Хабибуллин Ленар Габдуллович  ...  161,15  141,35  7,81  7,20
# 24       Архипов Николай Иванович  ...  213,51  211,19  8,69  6,42
# 25  Рахматуллин Ренат Даригатович  ...  115,13  153,27  5,61  7,55
# 26  Рахматуллин Ренат Даригатович  ...   20,90  160,60  6,38  6,82
# 27  Матвеев Евгений Александрович  ...  213,51  211,19  8,69  6,42
# 28   Хабибуллин Ленар Габдуллович  ...  117,70  153,45  6,82  5,98
# 29   Хабибуллин Ленар Габдуллович  ...   20,90  160,60  6,38  6,82
#
#    inv_item_type inv_item_name inv_item_weight inv_item_unit inv_item_dose  \
# 0            NaN           NaN             NaN           NaN           NaN
# 1            NaN           NaN             NaN           NaN           NaN
# 2            NaN           NaN             NaN           NaN           NaN
# 3            NaN           NaN             NaN           NaN           NaN
# 4            NaN           NaN             NaN           NaN           NaN
# 5            NaN           NaN             NaN           NaN           NaN
# 6            NaN           NaN             NaN           NaN           NaN
# 7            NaN           NaN             NaN           NaN           NaN
# 8            NaN           NaN             NaN           NaN           NaN
# 9            NaN           NaN             NaN           NaN           NaN
# 10           NaN           NaN             NaN           NaN           NaN
# 11           NaN           NaN             NaN           NaN           NaN
# 12           NaN           NaN             NaN           NaN           NaN
# 13           NaN           NaN             NaN           NaN           NaN
# 14           NaN           NaN             NaN           NaN           NaN
# 15           СЗР  Препарат 402          766,22             л          3,25
# 16           СЗР  Препарат 467           91,95             л          0,39
# 17           NaN           NaN             NaN           NaN           NaN
# 18           NaN           NaN             NaN           NaN           NaN
# 19           NaN           NaN             NaN           NaN           NaN
# 20           NaN           NaN             NaN           NaN           NaN
# 21           NaN           NaN             NaN           NaN           NaN
# 22           NaN           NaN             NaN           NaN           NaN
# 23           NaN           NaN             NaN           NaN           NaN
# 24           NaN           NaN             NaN           NaN           NaN
# 25           NaN           NaN             NaN           NaN           NaN
# 26           NaN           NaN             NaN           NaN           NaN
# 27           NaN           NaN             NaN           NaN           NaN
# 28           NaN           NaN             NaN           NaN           NaN
# 29           NaN           NaN             NaN           NaN           NaN
#
#    inv_item_date
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
# 5            NaT
# 6            NaT
# 7            NaT
# 8            NaT
# 9            NaT
# 10           NaT
# 11           NaT
# 12           NaT
# 13           NaT
# 14           NaT
# 15    2022-06-05
# 16    2022-06-05
# 17           NaT
# 18           NaT
# 19           NaT
# 20           NaT
# 21           NaT
# 22           NaT
# 23           NaT
# 24           NaT
# 25           NaT
# 26           NaT
# 27           NaT
# 28           NaT
# 29           NaT
#
# [30 rows x 40 columns]

# %%
df[df['work_id'] == '10DBA260-EEFA-488F-B7A2-2453B19E1103']
# Out:
#        season            field work_type                work_subtype  \
# 28318    2023  02.09.02.002.01       Сев  Сев без внесения удобрений
#
#        start_date end_date field_area  \
# 28318  28.04.2023      NaN      90,25
#
#                                                main_tech  \
# 28318  Трактор колесный Fendt 936 Vario, гос.ном. 568...
#
#                                                 add_tech  \
# 28318  Сеялка пропашная John Deere DB 55, зав.ном. 1L...
#
#                             mech  ...  p2o5   k2o humus    ph inv_item_type  \
# 28318  Петров Петр Александрович  ...  0,00  0,00  0,00  0,00        Семена
#
#                                 inv_item_name inv_item_weight inv_item_unit  \
# 28318  Гибрид Подсолнечника Фаусто F1 Express        15883,46        п. ед.
#
#       inv_item_dose inv_item_date
# 28318        175,99    2023-04-28
#
# [1 rows x 40 columns]

# %%
df[df['work_id'] == 'A773D4F0-C98F-401D-A572-A61336874E7A']
# Out:
#        season            field work_type                work_subtype  \
# 27490    2023  02.09.02.002.01       Сев  Сев без внесения удобрений
#
#        start_date end_date field_area  \
# 27490  27.04.2023      NaN      30,00
#
#                                                main_tech  \
# 27490  Трактор колесный Fendt 936 Vario, гос.ном. 568...
#
#                                                 add_tech  \
# 27490  Сеялка пропашная John Deere DB 55, зав.ном. 1L...
#
#                           mech  ...  p2o5   k2o humus    ph inv_item_type  \
# 27490  Газизов Рушат Рашитович  ...  0,00  0,00  0,00  0,00        Семена
#
#                                 inv_item_name inv_item_weight inv_item_unit  \
# 27490  Гибрид Подсолнечника Сузука F1 Express         5265,00        п. ед.
#
#       inv_item_dose inv_item_date
# 27490        175,50    2023-04-27
#
# [1 rows x 40 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv('merged-dataset.csv')
