# %%
import pandas as pd

df = pd.read_csv('fields82.csv', decimal=',')

# %%
df
# Out:
#                  field   region land_type  fertility_score  season  \
# 0      22.47.01.001.01    Алтай     пашня              NaN    2023
# 1      22.47.01.001.02    Алтай     пашня              NaN    2023
# 2      22.47.01.002.00    Алтай     пашня              4.0    2023
# 3      22.47.01.003.00    Алтай     пашня              4.0    2023
# 4      22.47.01.004.00    Алтай     пашня              3.0    2023
# ...                ...      ...       ...              ...     ...
# 16049  36.29.07.042.00  Воронеж     пашня              4.0    2024
# 16050  36.29.07.043.00  Воронеж     пашня              4.0    2024
# 16051  36.29.07.044.00  Воронеж     пашня              3.0    2024
# 16052  36.29.07.045.00  Воронеж     пашня              4.0    2024
# 16053  36.29.07.046.00  Воронеж     пашня              3.0    2024
#
#                          crop        crop_predecessor  crop_yearold    area  \
# 0           Оз.пшеница мягкая  Пар; Яр.пшеница мягкая           NaN  306.22
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('technology').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('seed_origin').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('land_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title area

from matplotlib import pyplot as plt
df['area'].plot(kind='hist', bins=20, title='area')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['fertility_score'].plot(kind='hist', bins=20, title='fertility_score')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['crop_yearold'].plot(kind='hist', bins=20, title='crop_yearold')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16054 entries, 0 to 16053
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   field             16054 non-null  object
#  1   region            16054 non-null  object
#  2   land_type         16054 non-null  object
#  3   fertility_score   15253 non-null  float64
#  4   season            16054 non-null  int64
#  5   crop              16054 non-null  object
#  6   crop_predecessor  15716 non-null  object
#  7   crop_yearold      2685 non-null   float64
#  8   area              16054 non-null  float64
#  9   hybrid            8678 non-null   object
#  10  reproduction      8193 non-null   object
#  11  seed_origin       8467 non-null   object
#  12  technology        8765 non-null   object
#  13  yield_plan        10696 non-null  float64
#  14  p2o5              16054 non-null  float64
#  15  k2o               16054 non-null  float64
# ...

# %%
df.describe()
# Out:
#        fertility_score        season  crop_yearold          area  \
# count     15253.000000  16054.000000   2685.000000  16054.000000
# mean          2.884810   2023.507350      2.682309     68.851674
# std           1.314812      0.499962      1.716928     85.001364
# min           0.000000   2023.000000      0.000000      0.090000
# 25%           2.000000   2023.000000      1.000000     13.992500
# 50%           3.000000   2024.000000      2.000000     40.705000
# 75%           4.000000   2024.000000      4.000000     94.100000
# max           5.000000   2024.000000     11.000000   1272.590000
#
#          yield_plan          p2o5           k2o         humus            ph
# count  10696.000000  16054.000000  16054.000000  16054.000000  16054.000000
# mean       5.032512     44.403504     89.152910     39.274405      3.584006
# std        6.036575     73.468058     88.791154     89.421015      2.978816
# min        0.090000      0.000000      0.000000      0.000000      0.000000
# ...

# %%
df1 = pd.read_csv('value82.csv', decimal=',')

# %%
df1
# Out:
#                   field inv_item_type inv_item_name  inv_item_weight  \
# 0       36.01.21.025.01     Удобрения  Удобрение 31         15017.60
# 1       36.14.12.064.00     Удобрения  Удобрение 31          6500.00
# 2       36.14.16.008.00     Удобрения  Удобрение 49          7865.00
# 3       36.14.16.008.00     Удобрения  Удобрение 49         10985.00
# 4       36.14.16.008.00     Удобрения  Удобрение 49         10985.00
# ...                 ...           ...           ...              ...
# 170808  47.22.06.019.00     Удобрения  Удобрение 31          5324.80
# 170809  47.22.06.019.00     Удобрения  Удобрение 31           319.49
# 170810  47.22.06.019.00     Удобрения  Удобрение 31           131.04
# 170811  72.22.02.055.00     Удобрения  Удобрение 49         13773.53
# 170812  72.22.10.015.00     Удобрения  Удобрение 31        137592.00
#
#        inv_item_unit  inv_item_dose inv_item_date  \
# 0                 кг         260.00    28.10.2024
# ...

# %%
from matplotlib import pyplot as plt
df1['inv_item_weight'].plot(kind='line', figsize=(8, 4), title='inv_item_weight')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df1['inv_item_dose'].plot(kind='line', figsize=(8, 4), title='inv_item_dose')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df1.plot(kind='scatter', x='inv_item_weight', y='inv_item_dose', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1.groupby('inv_item_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df2 = pd.read_csv('works82.csv', decimal=',')

# %%
df2
# Out:
#         season            field        work_type   work_subtype  start_date  \
# 0         2023  16.13.12.044.00  Обработка почвы    Боронование  29.04.2022
# 1         2023  16.13.12.017.00  Обработка почвы    Боронование  01.05.2022
# 2         2023  16.13.12.012.00  Обработка почвы    Боронование  02.05.2022
# 3         2023  16.13.12.012.00  Обработка почвы    Боронование  02.05.2022
# 4         2023  16.13.12.017.00  Обработка почвы    Боронование  02.05.2022
# ...        ...              ...              ...            ...         ...
# 174678    2024  54.17.12.029.00           Уборка  Подбор (корм)  27.10.2024
# 174679    2024  54.28.13.038.00           Уборка          Вывоз  27.10.2024
# 174680    2024  54.28.07.028.00  Обработка почвы    Культивация  28.10.2024
# 174681    2024  54.28.07.028.00  Обработка почвы    Культивация  28.10.2024
# 174682    2024  54.17.02.022.00           Уборка          Вывоз  28.10.2024
#
# ...

# %%
from matplotlib import pyplot as plt
df2['prod_weight'].plot(kind='line', figsize=(8, 4), title='prod_weight')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df2['prod_dry_perc'].plot(kind='line', figsize=(8, 4), title='prod_dry_perc')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df2.plot(kind='scatter', x='prod_weight', y='prod_dry_perc', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df2.groupby('work_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
